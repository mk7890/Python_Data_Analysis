# %% [markdown]
# <a href="https://colab.research.google.com/github/mk7890/Python_Data_Analysis/blob/main/Pandas_exercise3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Student Alcohol Consumption

# %%
url='https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/Students_Alcohol_Consumption/student-mat.csv'
df=pd.read_csv(url)
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
# For the purpose of this exercise slice the dataframe from 'school' until the 'guardian' column


# Slice the DataFrame from 'school' to 'guardian'
sliced_df = df.loc[:, 'school':'guardian']

# Print the resulting DataFrame
sliced_df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      reason guardian
# 0    course   mother
# 1    course   father
# 2     other   mother
# 3      home   mother
# 4      home   father
# ..      ...      ...
# 390  course    other
# 391  course   mother
# 392  course    other
# 393  course   mother
# 394  course   father
#
# [395 rows x 12 columns]

# %%
# Create a lambda function that will capitalize strings.

# Apply lambda function to capitalize strings in the sliced DataFrame
capitalized_sliced_df = sliced_df.applymap(lambda x: x.capitalize() if isinstance(x, str) else x)

# Print the resulting DataFrame
capitalized_sliced_df
# Out:
# <ipython-input-7-b6d16804032e>:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   capitalized_sliced_df = sliced_df.applymap(lambda x: x.capitalize() if isinstance(x, str) else x)
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       Gp   F   18       U     Gt3       A     4     4   At_home   Teacher
# 1       Gp   F   17       U     Gt3       T     1     1   At_home     Other
# 2       Gp   F   15       U     Le3       T     1     1   At_home     Other
# 3       Gp   F   15       U     Gt3       T     4     2    Health  Services
# 4       Gp   F   16       U     Gt3       T     3     3     Other     Other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     Ms   M   20       U     Le3       A     2     2  Services  Services
# 391     Ms   M   17       U     Le3       T     3     1  Services  Services
# 392     Ms   M   21       R     Gt3       T     1     1     Other     Other
# 393     Ms   M   18       R     Le3       T     3     2  Services     Other
# 394     Ms   M   19       U     Le3       T     1     1     Other   At_home
#
#      reason guardian
# 0    Course   Mother
# 1    Course   Father
# 2     Other   Mother
# 3      Home   Mother
# 4      Home   Father
# ..      ...      ...
# 390  Course    Other
# 391  Course   Mother
# 392  Course    Other
# 393  Course   Mother
# 394  Course   Father
#
# [395 rows x 12 columns]

# %%
# Capitalize both Mjob and Fjob

# Capitalize the values in the 'Mjob' and 'Fjob' columns
capitalized_sliced_df['Mjob'] = capitalized_sliced_df['Mjob'].apply(lambda x: x.capitalize() if isinstance(x, str) else x)
capitalized_sliced_df['Fjob'] = capitalized_sliced_df['Fjob'].apply(lambda x: x.capitalize() if isinstance(x, str) else x)

# Print the updated DataFrame
capitalized_sliced_df[['Mjob', 'Fjob']]
# Out:
#          Mjob      Fjob
# 0     At_home   Teacher
# 1     At_home     Other
# 2     At_home     Other
# 3      Health  Services
# 4       Other     Other
# ..        ...       ...
# 390  Services  Services
# 391  Services  Services
# 392     Other     Other
# 393  Services     Other
# 394     Other   At_home
#
# [395 rows x 2 columns]

# %%
# Print the last elements of the data set.
capitalized_sliced_df.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 390     Ms   M   20       U     Le3       A     2     2  Services  Services
# 391     Ms   M   17       U     Le3       T     3     1  Services  Services
# 392     Ms   M   21       R     Gt3       T     1     1     Other     Other
# 393     Ms   M   18       R     Le3       T     3     2  Services     Other
# 394     Ms   M   19       U     Le3       T     1     1     Other   At_home
#
#      reason guardian
# 390  Course    Other
# 391  Course   Mother
# 392  Course    Other
# 393  Course   Mother
# 394  Course   Father

# %%
# Did you notice the original dataframe is still lowercase? Why is that? Fix it and capitalize Mjob and Fjob.

# Capitalize all string values in the DataFrame
sliced_df = sliced_df.applymap(lambda x: x.capitalize() if isinstance(x, str) else x)

# Now capitalize Mjob and Fjob explicitly (optional, just to be sure)
sliced_df['Mjob'] = sliced_df['Mjob'].apply(lambda x: x.capitalize() if isinstance(x, str) else x)
sliced_df['Fjob'] = sliced_df['Fjob'].apply(lambda x: x.capitalize() if isinstance(x, str) else x)

# Print the updated DataFrame
sliced_df[['Mjob', 'Fjob']]
# Out:
# <ipython-input-12-0a3ec59d7516>:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   sliced_df = sliced_df.applymap(lambda x: x.capitalize() if isinstance(x, str) else x)
#          Mjob      Fjob
# 0     At_home   Teacher
# 1     At_home     Other
# 2     At_home     Other
# 3      Health  Services
# 4       Other     Other
# ..        ...       ...
# 390  Services  Services
# 391  Services  Services
# 392     Other     Other
# 393  Services     Other
# 394     Other   At_home
#
# [395 rows x 2 columns]

# %%
# Create a function called majority that returns a boolean value to a new column
# called legal_drinker (Consider majority as older than 17 years old)

# Define the majority function
def majority(age):
    return age > 17

# Apply the function to the 'age' column and create a new 'legal_drinker' column
sliced_df['legal_drinker'] = sliced_df['age'].apply(majority)

# Print the updated DataFrame with the new 'legal_drinker' column
sliced_df[['age', 'legal_drinker']]
# Out:
#      age  legal_drinker
# 0     18           True
# 1     17          False
# 2     15          False
# 3     15          False
# 4     16          False
# ..   ...            ...
# 390   20           True
# 391   17          False
# 392   21           True
# 393   18           True
# 394   19           True
#
# [395 rows x 2 columns]

# %%
# Multiply every number of the dataset by 10.

# Multiply every numerical value in the DataFrame by 10
sliced_df = sliced_df.applymap(lambda x: x * 10 if isinstance(x, (int, float)) else x)

# Print the updated DataFrame
sliced_df
# Out:
# <ipython-input-16-67d45bf579b1>:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   sliced_df = sliced_df.applymap(lambda x: x * 10 if isinstance(x, (int, float)) else x)
#     school sex   age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       Gp   F  1800       U     Gt3       A   400   400   At_home   Teacher
# 1       Gp   F  1700       U     Gt3       T   100   100   At_home     Other
# 2       Gp   F  1500       U     Le3       T   100   100   At_home     Other
# 3       Gp   F  1500       U     Gt3       T   400   200    Health  Services
# 4       Gp   F  1600       U     Gt3       T   300   300     Other     Other
# ..     ...  ..   ...     ...     ...     ...   ...   ...       ...       ...
# 390     Ms   M  2000       U     Le3       A   200   200  Services  Services
# 391     Ms   M  1700       U     Le3       T   300   100  Services  Services
# 392     Ms   M  2100       R     Gt3       T   100   100     Other     Other
# 393     Ms   M  1800       R     Le3       T   300   200  Services     Other
# 394     Ms   M  1900       U     Le3       T   100   100     Other   At_home
#
#      reason guardian  legal_drinker
# 0    Course   Mother            100
# 1    Course   Father              0
# 2     Other   Mother              0
# 3      Home   Mother              0
# 4      Home   Father              0
# ..      ...      ...            ...
# 390  Course    Other            100
# 391  Course   Mother              0
# 392  Course    Other            100
# 393  Course   Mother            100
# 394  Course   Father            100
#
# [395 rows x 13 columns]

# %% [markdown]
# # 4. Merge

# %% [markdown]
# - Auto MPG Cars dataset

# %%
import numpy as np
import pandas as pd

# %%
# Import the first dataset cars1 and cars2.

cars1_url = 'https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars1.csv'
cars2_url = 'https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars2.csv'

cars1 = pd.read_csv(cars1_url)
cars2 = pd.read_csv(cars2_url)

# %%
cars1
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 193  24.0          6           200         81    3012          17.6     76
# 194  22.5          6           232         90    3085          17.6     76
# 195  29.0          4            85         52    2035          22.2     76
# 196  24.5          4            98         60    2164          22.1     76
# 197  29.0          4            90         70    1937          14.2     76
#
#      origin                        car  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 0         1  chevrolet chevelle malibu         NaN          NaN          NaN
# 1         1          buick skylark 320         NaN          NaN          NaN
# 2         1         plymouth satellite         NaN          NaN          NaN
# 3         1              amc rebel sst         NaN          NaN          NaN
# 4         1                ford torino         NaN          NaN          NaN
# ..      ...                        ...         ...          ...          ...
# 193       1              ford maverick         NaN          NaN          NaN
# 194       1                 amc hornet         NaN          NaN          NaN
# 195       1         chevrolet chevette         NaN          NaN          NaN
# 196       1            chevrolet woody         NaN          NaN          NaN
# 197       2                  vw rabbit         NaN          NaN          NaN
#
#      Unnamed: 12  Unnamed: 13
# 0            NaN          NaN
# 1            NaN          NaN
# 2            NaN          NaN
# 3            NaN          NaN
# 4            NaN          NaN
# ..           ...          ...
# 193          NaN          NaN
# 194          NaN          NaN
# 195          NaN          NaN
# 196          NaN          NaN
# 197          NaN          NaN
#
# [198 rows x 14 columns]

# %%
cars2
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    33.0          4            91         53    1795          17.4     76
# 1    20.0          6           225        100    3651          17.7     76
# 2    18.0          6           250         78    3574          21.0     76
# 3    18.5          6           250        110    3645          16.2     76
# 4    17.5          6           258         95    3193          17.8     76
# ..    ...        ...           ...        ...     ...           ...    ...
# 195  27.0          4           140         86    2790          15.6     82
# 196  44.0          4            97         52    2130          24.6     82
# 197  32.0          4           135         84    2295          11.6     82
# 198  28.0          4           120         79    2625          18.6     82
# 199  31.0          4           119         82    2720          19.4     82
#
#      origin                 car
# 0         3         honda civic
# 1         1      dodge aspen se
# 2         1   ford granada ghia
# 3         1  pontiac ventura sj
# 4         1       amc pacer d/l
# ..      ...                 ...
# 195       1     ford mustang gl
# 196       2           vw pickup
# 197       1       dodge rampage
# 198       1         ford ranger
# 199       1          chevy s-10
#
# [200 rows x 9 columns]

# %%
# Oops, it seems our first dataset has some unnamed blank columns, fix cars1

cars1 = cars1.loc[:, 'mpg':'car']
cars1
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 193  24.0          6           200         81    3012          17.6     76
# 194  22.5          6           232         90    3085          17.6     76
# 195  29.0          4            85         52    2035          22.2     76
# 196  24.5          4            98         60    2164          22.1     76
# 197  29.0          4            90         70    1937          14.2     76
#
#      origin                        car
# 0         1  chevrolet chevelle malibu
# 1         1          buick skylark 320
# 2         1         plymouth satellite
# 3         1              amc rebel sst
# 4         1                ford torino
# ..      ...                        ...
# 193       1              ford maverick
# 194       1                 amc hornet
# 195       1         chevrolet chevette
# 196       1            chevrolet woody
# 197       2                  vw rabbit
#
# [198 rows x 9 columns]

# %%
cars1.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model', 'origin', 'car'],
#       dtype='object')

# %%
cars2.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model', 'origin', 'car'],
#       dtype='object')

# %%
# What is the number of observations in each dataset?

# Get the number of observations (rows) in the DataFrame
num_observations_cars1 = cars1.shape[0]
num_observations_cars2 = cars2.shape[0]

# Print the result
print("Number of observations cars1 :", num_observations_cars1)
print("Number of observations cars2 :", num_observations_cars2)
# Out:
# Number of observations cars1 : 198
# Number of observations cars2 : 200

# %%
# Join cars1 and cars2 into a single DataFrame called cars


# Concatenate the two DataFrames along rows (axis=0)
cars = pd.concat([cars1, cars2], axis=0, ignore_index=True)

# Print the resulting DataFrame
cars
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 393  27.0          4           140         86    2790          15.6     82
# 394  44.0          4            97         52    2130          24.6     82
# 395  32.0          4           135         84    2295          11.6     82
# 396  28.0          4           120         79    2625          18.6     82
# 397  31.0          4           119         82    2720          19.4     82
#
#      origin                        car
# 0         1  chevrolet chevelle malibu
# 1         1          buick skylark 320
# 2         1         plymouth satellite
# 3         1              amc rebel sst
# 4         1                ford torino
# ..      ...                        ...
# 393       1            ford mustang gl
# 394       2                  vw pickup
# 395       1              dodge rampage
# 396       1                ford ranger
# 397       1                 chevy s-10
#
# [398 rows x 9 columns]

# %%
# Oops, there is a column missing, called owners. Create a random number Series from 15,000 to 73,000.
# Add the column owners to cars

# Create a random number Series for the 'owners' column
cars['owners'] = np.random.randint(15000, 73001, size=len(cars))

# Print the resulting DataFrame
cars
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 393  27.0          4           140         86    2790          15.6     82
# 394  44.0          4            97         52    2130          24.6     82
# 395  32.0          4           135         84    2295          11.6     82
# 396  28.0          4           120         79    2625          18.6     82
# 397  31.0          4           119         82    2720          19.4     82
#
#      origin                        car  owners
# 0         1  chevrolet chevelle malibu   51871
# 1         1          buick skylark 320   57997
# 2         1         plymouth satellite   22709
# 3         1              amc rebel sst   43458
# 4         1                ford torino   64976
# ..      ...                        ...     ...
# 393       1            ford mustang gl   42061
# 394       2                  vw pickup   42367
# 395       1              dodge rampage   52594
# 396       1                ford ranger   49616
# 397       1                 chevy s-10   37805
#
# [398 rows x 10 columns]
