# %% [markdown]
# <a href="https://colab.research.google.com/github/mk7890/Python_Data_Analysis/blob/main/Pandas_exercise3_apply_merge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # 04_Apply/Students_Alcohol_Consumption

# %%
url='https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/Students_Alcohol_Consumption/student-mat.csv'
df=pd.read_csv(url)
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
# For the purpose of this exercise slice the dataframe from 'school' until the 'guardian' column


# Slice the DataFrame from 'school' to 'guardian'
sliced_df = df.loc[:, 'school':'guardian']

# Print the resulting DataFrame
sliced_df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      reason guardian
# 0    course   mother
# ...

# %%
# Create a lambda function that will capitalize strings.

# Apply lambda function to capitalize strings in the sliced DataFrame
capitalized_sliced_df = sliced_df.applymap(lambda x: x.capitalize() if isinstance(x, str) else x)

# Print the resulting DataFrame
capitalized_sliced_df
# Out:
# <ipython-input-5-b6d16804032e>:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   capitalized_sliced_df = sliced_df.applymap(lambda x: x.capitalize() if isinstance(x, str) else x)
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       Gp   F   18       U     Gt3       A     4     4   At_home   Teacher
# 1       Gp   F   17       U     Gt3       T     1     1   At_home     Other
# 2       Gp   F   15       U     Le3       T     1     1   At_home     Other
# 3       Gp   F   15       U     Gt3       T     4     2    Health  Services
# 4       Gp   F   16       U     Gt3       T     3     3     Other     Other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     Ms   M   20       U     Le3       A     2     2  Services  Services
# 391     Ms   M   17       U     Le3       T     3     1  Services  Services
# ...

# %%
# Capitalize both Mjob and Fjob

# Capitalize the values in the 'Mjob' and 'Fjob' columns
capitalized_sliced_df['Mjob'] = capitalized_sliced_df['Mjob'].apply(lambda x: x.capitalize() if isinstance(x, str) else x)
capitalized_sliced_df['Fjob'] = capitalized_sliced_df['Fjob'].apply(lambda x: x.capitalize() if isinstance(x, str) else x)

# Print the updated DataFrame
capitalized_sliced_df[['Mjob', 'Fjob']]
# Out:
#          Mjob      Fjob
# 0     At_home   Teacher
# 1     At_home     Other
# 2     At_home     Other
# 3      Health  Services
# 4       Other     Other
# ..        ...       ...
# 390  Services  Services
# 391  Services  Services
# 392     Other     Other
# 393  Services     Other
# 394     Other   At_home
#
# [395 rows x 2 columns]

# %%
# Print the last elements of the data set.
capitalized_sliced_df.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 390     Ms   M   20       U     Le3       A     2     2  Services  Services
# 391     Ms   M   17       U     Le3       T     3     1  Services  Services
# 392     Ms   M   21       R     Gt3       T     1     1     Other     Other
# 393     Ms   M   18       R     Le3       T     3     2  Services     Other
# 394     Ms   M   19       U     Le3       T     1     1     Other   At_home
#
#      reason guardian
# 390  Course    Other
# 391  Course   Mother
# 392  Course    Other
# 393  Course   Mother
# 394  Course   Father

# %%
# Did you notice the original dataframe is still lowercase? Why is that? Fix it and capitalize Mjob and Fjob.

# Capitalize all string values in the DataFrame
sliced_df = sliced_df.applymap(lambda x: x.capitalize() if isinstance(x, str) else x)

# Now capitalize Mjob and Fjob
sliced_df['Mjob'] = sliced_df['Mjob'].apply(lambda x: x.capitalize() if isinstance(x, str) else x)
sliced_df['Fjob'] = sliced_df['Fjob'].apply(lambda x: x.capitalize() if isinstance(x, str) else x)

# Print the updated DataFrame
sliced_df[['Mjob', 'Fjob']]
# Out:
# <ipython-input-8-0a3ec59d7516>:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   sliced_df = sliced_df.applymap(lambda x: x.capitalize() if isinstance(x, str) else x)
#          Mjob      Fjob
# 0     At_home   Teacher
# 1     At_home     Other
# 2     At_home     Other
# 3      Health  Services
# 4       Other     Other
# ..        ...       ...
# 390  Services  Services
# 391  Services  Services
# 392     Other     Other
# 393  Services     Other
# 394     Other   At_home
#
# [395 rows x 2 columns]

# %%
# Create a function called majority that returns a boolean value to a new column
# called legal_drinker (Consider majority as older than 17 years old)

# Define the majority function
def majority(age):
    return age > 17

# Apply the function to the 'age' column and create a new 'legal_drinker' column
sliced_df['legal_drinker'] = sliced_df['age'].apply(majority)

# Print the updated DataFrame with the new 'legal_drinker' column
sliced_df[['age', 'legal_drinker']]
# Out:
#      age  legal_drinker
# 0     18           True
# 1     17          False
# 2     15          False
# 3     15          False
# 4     16          False
# ..   ...            ...
# 390   20           True
# 391   17          False
# 392   21           True
# 393   18           True
# 394   19           True
#
# [395 rows x 2 columns]

# %%
# Multiply every number of the dataset by 10.

# Multiply every numerical value in the DataFrame by 10
sliced_df = sliced_df.applymap(lambda x: x * 10 if isinstance(x, (int, float)) else x)

# Print the updated DataFrame
sliced_df
# Out:
# <ipython-input-10-67d45bf579b1>:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   sliced_df = sliced_df.applymap(lambda x: x * 10 if isinstance(x, (int, float)) else x)
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       Gp   F  180       U     Gt3       A    40    40   At_home   Teacher
# 1       Gp   F  170       U     Gt3       T    10    10   At_home     Other
# 2       Gp   F  150       U     Le3       T    10    10   At_home     Other
# 3       Gp   F  150       U     Gt3       T    40    20    Health  Services
# 4       Gp   F  160       U     Gt3       T    30    30     Other     Other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     Ms   M  200       U     Le3       A    20    20  Services  Services
# 391     Ms   M  170       U     Le3       T    30    10  Services  Services
# 392     Ms   M  210       R     Gt3       T    10    10     Other     Other
# ...

# %% [markdown]
# # 04_Apply/US_Crime_Rates/Exercise

# %%
# import necessary packages
import numpy as np
import pandas as pd

# %%
# Step 2. Import the dataset.
# Step 3. Assign it to a variable called crime.
crime_rawData_url = 'https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv'
crime = pd.read_csv(crime_rawData_url)
crime.head()
# Out:
#    Year  Population    Total  Violent  Property  Murder  Forcible_Rape  \
# 0  1960   179323175  3384200   288460   3095700    9110          17190
# 1  1961   182992000  3488000   289390   3198600    8740          17220
# 2  1962   185771000  3752200   301510   3450700    8530          17550
# 3  1963   188483000  4109500   316970   3792500    8640          17650
# 4  1964   191141000  4564600   364220   4200400    9360          21420
#
#    Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 0   107840              154320    912100        1855400         328200
# 1   106670              156760    949600        1913000         336000
# 2   110860              164570    994300        2089600         366800
# 3   116470              174210   1086400        2297800         408300
# 4   130390              203050   1213200        2514400         472800

# %%
# Step 4. What is the type of the columns?
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                55 non-null     int64
#  1   Population          55 non-null     int64
#  2   Total               55 non-null     int64
#  3   Violent             55 non-null     int64
#  4   Property            55 non-null     int64
#  5   Murder              55 non-null     int64
#  6   Forcible_Rape       55 non-null     int64
#  7   Robbery             55 non-null     int64
#  8   Aggravated_assault  55 non-null     int64
#  9   Burglary            55 non-null     int64
#  10  Larceny_Theft       55 non-null     int64
#  11  Vehicle_Theft       55 non-null     int64
# dtypes: int64(12)
# memory usage: 5.3 KB

# %%
# Have you noticed that the type of Year is int64. But pandas has a different type to work with Time Series. Let's see it now.
# Step 5. Convert the type of the column Year to datetime64
crime['Year'] = pd.to_datetime(crime['Year'], format='%Y')
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                55 non-null     datetime64[ns]
#  1   Population          55 non-null     int64
#  2   Total               55 non-null     int64
#  3   Violent             55 non-null     int64
#  4   Property            55 non-null     int64
#  5   Murder              55 non-null     int64
#  6   Forcible_Rape       55 non-null     int64
#  7   Robbery             55 non-null     int64
#  8   Aggravated_assault  55 non-null     int64
#  9   Burglary            55 non-null     int64
#  10  Larceny_Theft       55 non-null     int64
#  11  Vehicle_Theft       55 non-null     int64
# dtypes: datetime64[ns](1), int64(11)
# memory usage: 5.3 KB

# %%
# Step 6. Set the Year column as the index of the dataframe
crime = crime.set_index('Year', drop=True)
crime.head()
# Out:
#             Population    Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1960-01-01   179323175  3384200   288460   3095700    9110          17190
# 1961-01-01   182992000  3488000   289390   3198600    8740          17220
# 1962-01-01   185771000  3752200   301510   3450700    8530          17550
# 1963-01-01   188483000  4109500   316970   3792500    8640          17650
# 1964-01-01   191141000  4564600   364220   4200400    9360          21420
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1960-01-01   107840              154320    912100        1855400
# 1961-01-01   106670              156760    949600        1913000
# 1962-01-01   110860              164570    994300        2089600
# 1963-01-01   116470              174210   1086400        2297800
# 1964-01-01   130390              203050   1213200        2514400
#
#             Vehicle_Theft
# Year
# 1960-01-01         328200
# 1961-01-01         336000
# ...

# %%
# Step 7. Delete the Total column
del crime['Total']
crime.head()
# Out:
#             Population  Violent  Property  Murder  Forcible_Rape  Robbery  \
# Year
# 1960-01-01   179323175   288460   3095700    9110          17190   107840
# 1961-01-01   182992000   289390   3198600    8740          17220   106670
# 1962-01-01   185771000   301510   3450700    8530          17550   110860
# 1963-01-01   188483000   316970   3792500    8640          17650   116470
# 1964-01-01   191141000   364220   4200400    9360          21420   130390
#
#             Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# Year
# 1960-01-01              154320    912100        1855400         328200
# 1961-01-01              156760    949600        1913000         336000
# 1962-01-01              164570    994300        2089600         366800
# 1963-01-01              174210   1086400        2297800         408300
# 1964-01-01              203050   1213200        2514400         472800

# %%
# Step 8. Group the year by decades and sum the values. Pay attention to the Population column number, summing this column is a mistake

# Convert the index to datetime format and extract only the year
crime.index = pd.to_datetime(crime.index).year

# Create a new column for decades based on the index
crime['Decade'] = (crime.index // 10) * 10

# Group by the 'Decade' column and sum all columns except 'Population'
summed_by_decade = crime.groupby('Decade').sum(numeric_only=True)

# For the 'Population' column, take the maximum value within each decade
summed_by_decade['Population'] = crime.groupby('Decade')['Population'].max()

# Display the result
print(summed_by_decade)
# Out:
#         Population   Violent   Property  Murder  Forcible_Rape   Robbery  \
# Decade
# 1970     318857056  65384309  517687418  952448        3999314  22904744
#
#         Aggravated_assault   Burglary  Larceny_Theft  Vehicle_Theft
# Decade
# 1970              37464999  133320955      327797108       56573743

# %%
# Step 9. What is the most dangerous decade to live in the US?


# Convert the index to datetime format and extract only the year
crime.index = pd.to_datetime(crime.index).year

# Create a new column for decades based on the index
crime['Decade'] = (crime.index // 10) * 10

# Group by the 'Decade' column and sum all columns except 'Population'
summed_by_decade = crime.groupby('Decade').sum(numeric_only=True)

# For the 'Population' column, take the maximum value within each decade
summed_by_decade['Population'] = crime.groupby('Decade')['Population'].max()

# Calculate the total crimes per decade (excluding 'Population')
summed_by_decade['Total_Crimes'] = summed_by_decade.drop(columns='Population').sum(axis=1)

# Find the decade with the highest total crimes
most_dangerous_decade = summed_by_decade['Total_Crimes'].idxmax()
most_dangerous_value = summed_by_decade['Total_Crimes'].max()

# Display the most dangerous decade and the crime count
print(f"Most dangerous decade: {most_dangerous_decade} with {most_dangerous_value} total crimes")

# Display the summarized DataFrame
print(summed_by_decade)
# Out:
# Most dangerous decade: 1970 with 1166085038 total crimes
#         Population   Violent   Property  Murder  Forcible_Rape   Robbery  \
# Decade
# 1970     318857056  65384309  517687418  952448        3999314  22904744
#
#         Aggravated_assault   Burglary  Larceny_Theft  Vehicle_Theft  \
# Decade
# 1970              37464999  133320955      327797108       56573743
#
#         Total_Crimes
# Decade
# 1970      1166085038

# %% [markdown]
# # 4. Merge

# %% [markdown]
# - 05_Merge/Auto_MPG dataset

# %%
import numpy as np
import pandas as pd

# %%
# Import the first dataset cars1 and cars2.

cars1_url = 'https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars1.csv'
cars2_url = 'https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars2.csv'

cars1 = pd.read_csv(cars1_url)
cars2 = pd.read_csv(cars2_url)

# %%
cars1
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 193  24.0          6           200         81    3012          17.6     76
# 194  22.5          6           232         90    3085          17.6     76
# 195  29.0          4            85         52    2035          22.2     76
# 196  24.5          4            98         60    2164          22.1     76
# 197  29.0          4            90         70    1937          14.2     76
#
# ...

# %%
cars2
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    33.0          4            91         53    1795          17.4     76
# 1    20.0          6           225        100    3651          17.7     76
# 2    18.0          6           250         78    3574          21.0     76
# 3    18.5          6           250        110    3645          16.2     76
# 4    17.5          6           258         95    3193          17.8     76
# ..    ...        ...           ...        ...     ...           ...    ...
# 195  27.0          4           140         86    2790          15.6     82
# 196  44.0          4            97         52    2130          24.6     82
# 197  32.0          4           135         84    2295          11.6     82
# 198  28.0          4           120         79    2625          18.6     82
# 199  31.0          4           119         82    2720          19.4     82
#
#      origin                 car
# 0         3         honda civic
# ...

# %%
# Oops, it seems our first dataset has some unnamed blank columns, fix cars1

cars1 = cars1.loc[:, 'mpg':'car']
cars1
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 193  24.0          6           200         81    3012          17.6     76
# 194  22.5          6           232         90    3085          17.6     76
# 195  29.0          4            85         52    2035          22.2     76
# 196  24.5          4            98         60    2164          22.1     76
# 197  29.0          4            90         70    1937          14.2     76
#
#      origin                        car
# ...

# %%
cars1.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model', 'origin', 'car'],
#       dtype='object')

# %%
cars2.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model', 'origin', 'car'],
#       dtype='object')

# %%
# What is the number of observations in each dataset?

# Get the number of observations (rows) in the DataFrame
num_observations_cars1 = cars1.shape[0]
num_observations_cars2 = cars2.shape[0]

# Print the result
print("Number of observations cars1 :", num_observations_cars1)
print("Number of observations cars2 :", num_observations_cars2)
# Out:
# Number of observations cars1 : 198
# Number of observations cars2 : 200

# %%
# Join cars1 and cars2 into a single DataFrame called cars


# Concatenate the two DataFrames along rows (axis=0)
cars = pd.concat([cars1, cars2], axis=0, ignore_index=True)

# Print the resulting DataFrame
cars
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 393  27.0          4           140         86    2790          15.6     82
# 394  44.0          4            97         52    2130          24.6     82
# 395  32.0          4           135         84    2295          11.6     82
# 396  28.0          4           120         79    2625          18.6     82
# 397  31.0          4           119         82    2720          19.4     82
#
#      origin                        car
# ...

# %%
# Step 7. Oops, there is a column missing, called owners. Create a random number Series from 15,000 to 73,000.
# Step 8. Add the column owners to cars

# Create a random number Series for the 'owners' column
cars['owners'] = np.random.randint(15000, 73001, size=len(cars))

# Print the resulting DataFrame
cars
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 393  27.0          4           140         86    2790          15.6     82
# 394  44.0          4            97         52    2130          24.6     82
# 395  32.0          4           135         84    2295          11.6     82
# 396  28.0          4           120         79    2625          18.6     82
# 397  31.0          4           119         82    2720          19.4     82
#
#      origin                        car  owners
# ...

# %% [markdown]
# - 05_Merge/Fictitous Names/Exercise

# %%
# Step 1. Import the necessary libraries
import numpy as np
import pandas as pd

# %%
# Step 2. Create the 3 DataFrames based on the following raw data
raw_data_1 = {
        'subject_id': ['1', '2', '3', '4', '5'],
        'first_name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'],
        'last_name': ['Anderson', 'Ackerman', 'Ali', 'Aoni', 'Atiches']}

raw_data_2 = {
        'subject_id': ['4', '5', '6', '7', '8'],
        'first_name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'],
        'last_name': ['Bonder', 'Black', 'Balwner', 'Brice', 'Btisan']}

raw_data_3 = {
        'subject_id': ['1', '2', '3', '4', '5', '7', '8', '9', '10', '11'],
        'test_id': [51, 15, 15, 61, 16, 14, 15, 1, 61, 16]}

# %%
# Step 3. Assign each to a variable called data1, data2, data3
data1 = pd.DataFrame(raw_data_1)
print('data1\n',data1)
data2 = pd.DataFrame(raw_data_2)
print('data2\n', data2)
data3 = pd.DataFrame(raw_data_3)
print('data3\n',data3)
# Out:
# data1
#    subject_id first_name last_name
# 0          1       Alex  Anderson
# 1          2        Amy  Ackerman
# 2          3      Allen       Ali
# 3          4      Alice      Aoni
# 4          5     Ayoung   Atiches
# data2
#    subject_id first_name last_name
# 0          4      Billy    Bonder
# 1          5      Brian     Black
# 2          6       Bran   Balwner
# 3          7      Bryce     Brice
# 4          8      Betty    Btisan
# data3
#    subject_id  test_id
# 0          1       51
# 1          2       15
# 2          3       15
# 3          4       61
# 4          5       16
# 5          7       14
# 6          8       15
# 7          9        1
# 8         10       61
# 9         11       16

# %%
# Step 4. Join the two dataframes along rows and assign all_data (data1 & data2)
all_data = pd.concat([data1, data2], axis=0)
all_data
# Out:
#   subject_id first_name last_name
# 0          1       Alex  Anderson
# 1          2        Amy  Ackerman
# 2          3      Allen       Ali
# 3          4      Alice      Aoni
# 4          5     Ayoung   Atiches
# 0          4      Billy    Bonder
# 1          5      Brian     Black
# 2          6       Bran   Balwner
# 3          7      Bryce     Brice
# 4          8      Betty    Btisan

# %%
# Step 5. Join the two dataframes along columns and assing to all_data_col
all_data_col = pd.concat([data1, data2], axis=1)
all_data_col
# Out:
#   subject_id first_name last_name subject_id first_name last_name
# 0          1       Alex  Anderson          4      Billy    Bonder
# 1          2        Amy  Ackerman          5      Brian     Black
# 2          3      Allen       Ali          6       Bran   Balwner
# 3          4      Alice      Aoni          7      Bryce     Brice
# 4          5     Ayoung   Atiches          8      Betty    Btisan

# %%
# Step 6. Print data3
data3
# Out:
#   subject_id  test_id
# 0          1       51
# 1          2       15
# 2          3       15
# 3          4       61
# 4          5       16
# 5          7       14
# 6          8       15
# 7          9        1
# 8         10       61
# 9         11       16

# %%
# Step 7. Merge all_data and data3 along the subject_id value
all_data_data3 = pd.merge(all_data, data3, on='subject_id')
all_data_data3
# Out:
#   subject_id first_name last_name  test_id
# 0          1       Alex  Anderson       51
# 1          2        Amy  Ackerman       15
# 2          3      Allen       Ali       15
# 3          4      Alice      Aoni       61
# 4          5     Ayoung   Atiches       16
# 5          4      Billy    Bonder       61
# 6          5      Brian     Black       16
# 7          7      Bryce     Brice       14
# 8          8      Betty    Btisan       15

# %%
# Step 8. Merge only the data that has the same 'subject_id' on both data1 and data2
data1_data2 = pd.merge(data1, data2, on='subject_id')
data1_data2
# Out:
#   subject_id first_name_x last_name_x first_name_y last_name_y
# 0          4        Alice        Aoni        Billy      Bonder
# 1          5       Ayoung     Atiches        Brian       Black

# %%
# Step 9. Merge all values in data1 and data2, with matching records from both sides where available.
data1_data2_all = pd.merge(data1, data2, on='subject_id', how='outer')
data1_data2_all
# Out:
#   subject_id first_name_x last_name_x first_name_y last_name_y
# 0          1         Alex    Anderson          NaN         NaN
# 1          2          Amy    Ackerman          NaN         NaN
# 2          3        Allen         Ali          NaN         NaN
# 3          4        Alice        Aoni        Billy      Bonder
# 4          5       Ayoung     Atiches        Brian       Black
# 5          6          NaN         NaN         Bran     Balwner
# 6          7          NaN         NaN        Bryce       Brice
# 7          8          NaN         NaN        Betty      Btisan

# %% [markdown]
# - 05_Merge/Housing Market dataset
#
# Housing Market
#
# Introduction:
#
# This time we will create our own dataset with fictional numbers to describe a house market. As we are going to create random data don't try to reason of the numbers.

# %%
# import necessary libraries
import numpy as np
import pandas as pd

# %%
# Step 2. Create 3 differents Series, each of length 100, as follows:
# The first a random number from 1 to 4
# The second a random number from 1 to 3
# The third a random number from 10,000 to 30,000
series_1 = pd.Series(np.random.randint(1, 5, size=100))
series_2 = pd.Series(np.random.randint(1, 4, size=100))
series_3 = pd.Series(np.random.randint(10000, 30001, size=100))

# %%
# Step 3. # Create a DataFrame by joining the Series as columns
df = pd.concat([series_1, series_2, series_3], axis=1)

# Rename the columns for clarity
df.columns = ['Series_1', 'Series_2', 'Series_3']

# Display the first few rows of the DataFrame
df.head()
# Out:
#    Series_1  Series_2  Series_3
# 0         2         2     15848
# 1         2         1     21690
# 2         1         1     15836
# 3         3         3     21018
# 4         2         1     14285

# %%
# Step 4. Change the name of the columns to bedrs, bathrs, price_sqr_meter
df.columns = ['bedrs', 'bathrs', 'price_sqr_meter']
df.head()
# Out:
#    bedrs  bathrs  price_sqr_meter
# 0      2       2            15848
# 1      2       1            21690
# 2      1       1            15836
# 3      3       3            21018
# 4      2       1            14285

# %%
# Step 5. Create a one column DataFrame with the values of the 3 Series and assign it to 'bigcolumn'
bigcolumn = pd.concat([series_1, series_2, series_3], axis=0)
# bigcolumn = bigcolumn.to_frame()
bigcolumn
# Out:
# 0         2
# 1         2
# 2         1
# 3         3
# 4         2
#       ...
# 95    14394
# 96    16758
# 97    12818
# 98    29759
# 99    26259
# Length: 300, dtype: int64

# %%
# Step 6. Oops, it seems it is going only until index 99. Is it true?

max_index = df.index.max()

print(f"The maximum index of the DataFrame is: {max_index}")
# Out:
# The maximum index of the DataFrame is: 99

# %%
# Step 7. Reindex the DataFrame so it goes from 0 to 299
bigcolumn = bigcolumn.reset_index(drop=True)
bigcolumn
# Out:
# 0          2
# 1          2
# 2          1
# 3          3
# 4          2
#        ...
# 295    14394
# 296    16758
# 297    12818
# 298    29759
# 299    26259
# Length: 300, dtype: int64
